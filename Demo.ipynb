# %% [markdown]
# <a href="https://colab.research.google.com/github/jlwssw/LogicDST/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programming Lab 0: Demo how to use computers to evaluate expressions
# In this lab we will practice how to use Google Colab to let computers evaluate an expression. We will introduce terms and a format that will stay consistent with all hands-on labs.
#
# Learning Goals:
#
#
#
#
# 1.   Know how to complete Task 0
#
#
#
# 1.   Know where to type an expression
# 2.   Know how to evaluate it using  the computer
#
#
# 1.  Know where to find the output
#
# 2.   Know how to save a "Copy to Drive"
#
#
#
#
#
#
#
#
#
# **Read and follow the instructions below carefully**

# %% [markdown]
# ## Setting the Stage
# The tasks of each hands-on lab depend on some functions being defined. However, they must be activated before you can use them. Without activating them, when you complete the tasks below, you might come across very strange errors.
#
# **Your Task:** Complete task 0 before other tasks. (In case you click the "Show code" below but then want to hide the code again, click the down arror to the lest of "Task 0".

# %%
# @title Task 0: Hover your mouse below and then click the play circle button below to activate the functions for this lab
#The represent the function view0f as a set of pair
# Python does not directly support definition of function in this way
# so we need do addition work to allow a function call.or use.it as a function
# in the prefix form. Code written around 2023. This comment Feb 2026
viewsOf = {("Never Be the Same", 3), ("Havana", 20), ("Love You Like A Love Song", 7),("Come & Get It", 8)}
singerOf = {("Never Be the Same", "Camila Cabello"), ("Havana", "Camila Cabello"), ("Love You Like A Love Song", "Selena Gomez"),("Come & Get It", "Selena Gomez")}
class MyFunctionAsSet:
    def __init__(self, givenSet):
        self.data = givenSet
    def __call__(self, input):
        image = {y for (x, y) in self.data if x == input}
        if len(image) == 1: output = next(iter(image))
        else:
          output = None
          print("Sorry, I don't have the information for \"{input}\"") # None
        return output
viewsOf = MyFunctionAsSet(viewsOf)
singerOf = MyFunctionAsSet(singerOf)
print("Functions are activated.")

# %% [markdown]
# ## Task 1 - let computers evaluate an expression!
#
# **Your Task**
#
# 1. Write an experssion to answer the question
#
#     *What is the number of views of the song "Come & Get It"?*
#
# 2. Evaluate the expression using the computer. Check if it agrees with the data set we use.
#
#
#
#
# | Song Name | Number of Views | Singer Name |
# |---------------|--------------|--------|
# | Love You Like a Love Song |	7 |	Selena Gomez |
# | Come & Get It |	8 |	Selena Gomez	|
# | Never Be the Same|	3 |	Camila Cabello |
# | Havana|	20 |	Camila Cabello |
#
# Assume we have a function *viewsOf* which intended specification is:
#
# **Function name**:  *viewsOf*
#
# **Input**:  a song
#
# **Output**: the views of the song
#
# **Side effect**: None

# %%
viewsOf("Come & Get It")

# %% [markdown]
# ## Task 2 - let computers evaluate an expression!
#
# **Your Task**
#
# Assume we have a function *singerOf* which intended specification is:
#
# **Function name**:  *singerOf*
#
# **Input**:  a song
#
# **Output**: the singer of the song
#
# **Side effect**: None
#
# 1. Write an expression to answer the question:
#
#     *What is the singer of the song "Never Be the Same"?*
#
# 2. Evaluate the expression. Check if the value given by the computer is correct using the table earlier

# %%
singerOf("Never Be the Same")

# %% [markdown]
# Version 2026 Spring (02/20)
